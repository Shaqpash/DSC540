# %%
#DSC0540 Week 7 and 8 exercuse
#Shaquiel Pashtunyar
#Complete 8 excercises

# %%
import pandas as pd
import numpy as np
Candy = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")

# %%
#got my data set I plan on working with
Candy
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
Candy.columns
# Out:
# Index(['Timestamp', 'Are you going actually going trick or treating yourself?',
#        'Your gender:', 'How old are you?', 'Which country do you live in?',
#        'Which state, province, county do you live in?', ' [100 Grand Bar]',
#        ' [Anonymous brown globs that come in black and orange wrappers]',
#        ' [Any full-sized candy bar]', ' [Black Jacks]',
#        ...
#        'Please estimate the degree(s) of separation you have from the following celebrities [JK Rowling]',
#        'Please estimate the degree(s) of separation you have from the following celebrities [JJ Abrams]',
#        'Please estimate the degree(s) of separation you have from the following celebrities [Beyoncé]',
#        'Please estimate the degree(s) of separation you have from the following celebrities [Bieber]',
#        'Please estimate the degree(s) of separation you have from the following celebrities [Kevin Bacon]',
# ...

# %%
#Excercise 1, dropping columns with all NA which is only the final column in the dataset, went from 123 to 122 in my table shape
Candy = Candy.dropna(axis=1, how='all')

# %%
Candy.shape
# Out:
# (1259, 122)

# %%
#Excercise 2 I can fill NA with 0. I don't want to make this permanent but maybe for select columns in the future
Candy.fillna(0)
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
#Excercise 3 I Can replace actually thats me with NaN as that means nothing to me, also age as 0 can be removed
Candy = Candy.replace("Actually, that's me.", np.nan)
Candy
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
Candy.index
# Out:
# RangeIndex(start=0, stop=1259, step=1)

# %%
#Excercise 4 I can stack the data to easily search up information by an index
stacked = Candy.stack()

# %%
stacked[2]
# Out:
# Timestamp                                                                                                                                            2016-10-24 05:13:06.734000
# Are you going actually going trick or treating yourself?                                                                                                                     No
# Your gender:                                                                                                                                                             Female
# How old are you?                                                                                                                                                           48.0
# Which country do you live in?                                                                                                                                                US
# ...

# %%
#Unstacking lets me go back :D
stacked.unstack()
# Out:
#                        Timestamp  \
# 0     2016-10-24 05:09:23.033000
# 1     2016-10-24 05:09:54.798000
# 2     2016-10-24 05:13:06.734000
# 3     2016-10-24 05:14:17.192000
# 4     2016-10-24 05:14:24.625000
# ...                          ...
# 1254  2016-10-29 16:53:52.516000
# 1255  2016-10-30 06:53:54.735000
# 1256  2016-10-30 11:06:10.827000
# 1257  2016-10-30 16:07:26.539000
# 1258  2016-10-30 17:06:45.660000
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# ...

# %%
#Bringing in Candy data workbook
Candydata = pd.read_excel("CandyData.xlsx")
Candydata
# Out:
# C:\Users\spashtunyar\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  ITEM    JOY  DESPAIR  \
# 0                             York Peppermint Patties    634       78
# 1                                Whole Wheat anything     21      419
# 2                                         White Bread     15      473
# 3                                             Vicodin    323      210
# 4                                                Twix    770       26
# ..                                                ...    ...      ...
# 82                                        Black Jacks     34      252
# 83                           Any full-sized candy bar    828       13
# 84  Anonymous brown globs that come in black and o...    120      663
# 85                                      100 Grand Bar    570       34
# ...

# %%
from datetime import datetime

# %%
Candy["Timestamp2"] = Candy["Timestamp"].dt.strftime('%Y/%m/%d')

# %%
#Excercise 5 converting the datetime(String) to just dates(datetime)
Candy
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# ...                      ...
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                    No               Male
# 1                                                    No               Male
# 2                                                    No             Female
# 3                                                    No               Male
# 4                                                   Yes               Male
# ...                                                 ...                ...
# 1254                                                 No             Female
# ...

# %%
#Excercise 6 Create a date range of just the 8 days the survey gathered data on
index = pd.date_range('2016-10-24' , periods =8)

# %%
index
# Out:
# DatetimeIndex(['2016-10-24', '2016-10-25', '2016-10-26', '2016-10-27',
#                '2016-10-28', '2016-10-29', '2016-10-30', '2016-10-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
start_date = '2016/10/24'
end_date = '2016/10/26'
Candy['mask'] = (Candy["Timestamp2"] > start_date) & (Candy["Timestamp2"] <= end_date)

# %%
Candydata
# Out:
#                                                  ITEM    JOY  DESPAIR  \
# 0                             York Peppermint Patties    634       78
# 1                                Whole Wheat anything     21      419
# 2                                         White Bread     15      473
# 3                                             Vicodin    323      210
# 4                                                Twix    770       26
# ..                                                ...    ...      ...
# 82                                        Black Jacks     34      252
# 83                           Any full-sized candy bar    828       13
# 84  Anonymous brown globs that come in black and o...    120      663
# 85                                      100 Grand Bar    570       34
# 86                                                NaN  26204    17563
#
#     NET FEELIES  NET CLOUT  DESPAIR (NEG)
# 0         556.0   1.639118          -78.0
# ...

# %%
#Creating the top function based on net clout
def top(df, n = 5, column = 'NET CLOUT'):
    return df.sort_values(by=column)[-n:]

# %%
#Top 6 clout candy bars
top(Candydata, n=6)
# Out:
#                           ITEM    JOY  DESPAIR  NET FEELIES  NET CLOUT  \
# 4                         Twix    770       26        744.0   1.832497
# 83    Any full-sized candy bar    828       13        815.0   1.936093
# 26                Peanut M&M’s    773       75        698.0   1.952208
# 47                     Kit Kat    894       15        879.0   2.092638
# 23  Reese’s Peanut Butter Cups    983       47        936.0   2.371196
# 86                         NaN  26204    17563          NaN        NaN
#
#     DESPAIR (NEG)
# 4           -26.0
# 83          -13.0
# 26          -75.0
# 47          -15.0
# 23          -47.0
# 86            NaN

# %%
#Excercise 7 we apply the top function to group values by JOY with clout from lowest to higest
Candydata.groupby('JOY').apply(top)
# Out:
#                                 ITEM    JOY  DESPAIR  NET FEELIES  NET CLOUT  \
# JOY
# 14    77           Broken glow stick     14      579       -565.0   1.365164
# 15    2                  White Bread     15      473       -458.0   1.123440
# 21    9                     Sweetums     21       92        -71.0   0.260141
#       1         Whole Wheat anything     21      419       -398.0   1.012938
#       60     Gum from baseball cards     21      471       -450.0   1.132649
# ...                              ...    ...      ...          ...        ...
# 773   26                Peanut M&M’s    773       75        698.0   1.952208
# 828   83    Any full-sized candy bar    828       13        815.0   1.936093
# 894   47                     Kit Kat    894       15        879.0   2.092638
# 983   23  Reese’s Peanut Butter Cups    983       47        936.0   2.371196
# 26204 86                         NaN  26204    17563          NaN        NaN
#
#           DESPAIR (NEG)
# JOY
# ...

# %%
#Excercise 8  creating a pivot table on clout and items
CandyPivot = Candydata.pivot_table(index = ['ITEM','NET CLOUT'])
CandyPivot
# Out:
#                                                               DESPAIR  \
# ITEM                                               NET CLOUT
# 100 Grand Bar                                      1.390488        34
# Anonymous brown globs that come in black and or... 1.802569       663
# Any full-sized candy bar                           1.936093        13
# Black Jacks                                        0.658410       252
# Bonkers                                            0.299277        99
# ...                                                               ...
# Twix                                               1.832497        26
# Vicodin                                            1.227036       210
# White Bread                                        1.123440       473
# Whole Wheat anything                               1.012938       419
# York Peppermint Patties                            1.639118        78
#
# ...
